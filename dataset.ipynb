# %%
import requests

headers = {
    "Authorization": "DWE1CBvbUoFeOld0fhtNLVV82yibgo7ITKTQ48kC"
}

response = requests.get(
    "https://api.grid.gg/file-download/end-state/grid/series/2589176",
    headers = headers
)

# %%
print(response.status_code)
print(response.headers.get("Content-Type"))
print(len(response.content))
# Out:
# 401
# text/plain; charset=utf-8
# 23

# %%
import json

data = response.json()

with open("series_2589176_raw.json", "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\hitan\anaconda3\envs\your_env_py312\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\hitan\anaconda3\envs\your_env_py312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
# ...

# %%
import requests
import json

url = "https://api.grid.gg/central-data/graphql"

headers = {
    "Authorization": "DWE1CBvbUoFeOld0fhtNLVV82yibgo7ITKTQ48kC",
    "Content-Type": "application/json"
}

response = requests.post(url, headers=headers, json={"query": query})
print(response.status_code)
data = response.json()
print(json.dumps(data, indent=2))
# Out:
# 200
# {
#   "errors": [
#     {
#       "message": "Requester unauthorized to make query",
#       "path": [
#         "queryValue"
#       ],
#       "extensions": {
#         "errorType": "UNAUTHENTICATED",
#         "serviceName": "gql-cd-query",
#         "code": "DOWNSTREAM_SERVICE_ERROR"
#       }
#     }
#   ],
#   "data": null
# }

# %%
import requests

series_id = "2843071"  # 👈 pick one from your list

headers = {
    "Authorization": "DWE1CBvbUoFeOld0fhtNLVV82yibgo7ITKTQ48kC"
}

url = f"https://api.grid.gg/file-download/end-state/grid/series/{series_id}"

response = requests.get(url, headers=headers)

print("Status:", response.status_code)
print("Content length:", len(response.content))
print("Content-Type:", response.headers.get("Content-Type"))
# Out:
# Status: 401
# Content length: 23
# Content-Type: text/plain; charset=utf-8

# %%
import requests

headers = {
    "x-api-key": "DWE1CBvbUoFeOld0fhtNLVV82yibgo7ITKTQ48kC"
}

response = requests.get(
    "https://api.grid.gg/file-download/end-state/grid/series/2843071",
    headers = headers
)

print("Status:", response.status_code)
print("Content length:", len(response.content))
print("Content-Type:", response.headers.get("Content-Type"))
# Out:
# Status: 200
# Content length: 1599029
# Content-Type: application/json; charset=utf-8

# %%
import json

data = response.json()

series_id = "2843071"  # or whichever worked

with open(f"series_{series_id}_raw.json", "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2)
